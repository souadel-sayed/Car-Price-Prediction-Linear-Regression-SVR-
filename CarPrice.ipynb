# %% [markdown]
# # CarPriceNotebook

# %% [markdown]
# ## describtion about data
# > Chinese automobile company Geely Auto aspires to enter the US market by setting up their manufacturing unit there and producing cars locally to give competition to their US and European counterparts.
#
# >They have contracted an automobile consulting company to understand the factors on which the pricing of cars depends. Specifically, they want to understand the factors affecting the pricing of cars in the American market, since those may be very different from the Chinese market. The company wants to know:
#
# - Which variables are significant in predicting the price of a car
# - How well those variables describe the price of a car
# - what the columns mean
# - car_ID  ( the id of car )
# -  symboling (sign o things in screan to give information like 1. Oil Pressure Warning Light 2. Tire Pressure Warning Light)
# -  CarName the name of car
# -  fueltype (the type of fuel)
# -  aspiration          (A naturally aspirated engine, also known as a normally aspirated engine, and abbreviated to N/A or NA,    is an internal combustion engine in which air intake depends solely on atmospheric pressure and does not have forced induction through a turbocharger or a supercharger.)
# - doornumber
# - carbody (The outer covering of a motor vehicle )
# - drivewheel(A drive wheel is a wheel of a motor vehicle that transmits force, transforming torque into tractive force from the tires to the road, causing the vehicle to move. The powertrain delivers enough torque to the wheel to overcome stationary forces, resulting in the vehicle moving forwards or backwards.)
# - enginelocation
# - wheelbase (the distance between the front and rear axles of an automotive vehicle.)
# - 'carlength'
# - 'carwidth'
# -  'carheight'
# - 'curbweight'
# - 'enginetype'
# - 'cylindernumber'
# - 'enginesize'
# -  'fuelsystem'(The fuel system in a vehicle is the combination of parts needed to carry fuel into and out of the engine. Once a fuel system is clean the tank should be completely filled. The main parts of a fuel system are the fuel tank, fuel lines, fuel pump, fuel filters, and a distribution device.)
# - boreratio(Bore-Stroke Ratio is the ratio between the dimensions of the engine cylinder bore diameter to its piston stroke-length. The cylinder bore diameter divided by the stroke-length gives the Bore-to-Stroke ratio. The 'Bore-stroke ratio' is an important factor which determines engine's power & torque characteristics)
# -  stroke (The stroke length is how far the piston travels in the cylinder, which is determined by the cranks on the crankshaft. Engine displacement is calculated by multiplying the cross-section area of the cylinder (determined by the bore) by the stroke length.)
# - compressionratio
# - horsepower
# - peakrpm (Car engine rpm increases as you press the accelerator, as does power — at least to a point. An engine doesn't necessarily produce its maximum power at its highest rpm. Engine specifications typically present the peak horsepower figure followed by the rpm at which it occurs, such as 252 hp at 5,600 rpm.)
# - citympg (City MPG: the score a car will get on average in city conditions, with stopping and starting at lower speeds. And, combined MPG, a combined average of highway and city MPG)
# - highwaympg (the average a car will get while driving on an open stretch of road without stopping or starting, typically at a higher speed. City MPG: the score a car will get on average in city conditions, with stopping and starting at lower speeds. And, combined MPG, a combined average of highway and city MPG.)
# -  price

# %% [markdown]
# ## import libraries

# %%
import pandas as pd
import numpy as np 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## read data

# %%
df= pd.read_csv("CarPrice_Assignment.csv")
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0  convertible        rwd          front       88.6      168.8      64.1
# 1  convertible        rwd          front       88.6      168.8      64.1
# 2    hatchback        rwd          front       94.5      171.2      65.5
# 3        sedan        fwd          front       99.8      176.6      66.2
# 4        sedan        4wd          front       99.4      176.6      66.4
#
# ...

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df.shape
# Out:
# (205, 26)

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.drop('car_ID',axis=1,inplace=True)

# %%
df.head()
# Out:
#    symboling                   CarName fueltype aspiration doornumber  \
# 0          3        alfa-romero giulia      gas        std        two
# 1          3       alfa-romero stelvio      gas        std        two
# 2          1  alfa-romero Quadrifoglio      gas        std        two
# 3          2               audi 100 ls      gas        std       four
# 4          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0  convertible        rwd          front       88.6      168.8      64.1
# 1  convertible        rwd          front       88.6      168.8      64.1
# 2    hatchback        rwd          front       94.5      171.2      65.5
# 3        sedan        fwd          front       99.8      176.6      66.2
# 4        sedan        4wd          front       99.4      176.6      66.4
#
#    carheight  curbweight enginetype cylindernumber  enginesize fuelsystem  \
# ...

# %% [markdown]
# - sea the content of columns to inshure no null values

# %%
for col in df.columns:
    print("columns name : ",col)
    print("count of every value ")
    print(df[col].value_counts())
    print("///////////////////////")
# Out:
# columns name :  symboling
# count of every value
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: symboling, dtype: int64
# ///////////////////////
# columns name :  CarName
# count of every value
# toyota corona                      6
# toyota corolla                     6
# peugeot 504                        6
# subaru dl                          4
# mitsubishi mirage g4               3
# toyota mark ii                     3
# honda civic                        3
# mazda 626                          3
# mitsubishi outlander               3
# mitsubishi g4                      3
# mazda rx-7 gs                      2
# mazda glc                          2
# nissan latio                       2
# mazda rx-4                         2
# toyota corolla 1200                2
# porsche cayenne                    2
# toyota corolla liftback            2
# volkswagen dasher                  2
# volvo 244dl                        2
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe(include="all").transpose()
# Out:
#                   count unique            top freq          mean          std  \
# symboling         205.0    NaN            NaN  NaN      0.834146     1.245307
# CarName             205    147  toyota corona    6           NaN          NaN
# fueltype            205      2            gas  185           NaN          NaN
# aspiration          205      2            std  168           NaN          NaN
# doornumber          205      2           four  115           NaN          NaN
# carbody             205      5          sedan   96           NaN          NaN
# drivewheel          205      3            fwd  120           NaN          NaN
# enginelocation      205      2          front  202           NaN          NaN
# wheelbase         205.0    NaN            NaN  NaN     98.756585     6.021776
# carlength         205.0    NaN            NaN  NaN    174.049268    12.337289
# carwidth          205.0    NaN            NaN  NaN     65.907805     2.145204
# ...

# %% [markdown]
# > from this describtion we sea
# - symboling the maximum value is 3,minmum is 2 and mean is 1
# - CarName the maximum value is 6 for peugeot 504
# - fueltype 185 from 205 use gas and we have only 2 types
# - aspiration 168 from 205 use std and we have only 2 types
# - doornumber 115 from 205 use four and we have only 2 types
# - carbody 96 from 205 use sedan and we have only 5 types
# - drivewheel 120 from 205 use fwd and we have only 3 types
# - enginelocation 202 from 205 use front and we have only 2 types
# - enginetype 148 from 205 use ohc and we have only 7 types
# - price the maximum value is 3 , minmum is 5118.0
# - horsepower the maximum value 288.0.0 , minmum is 48.0
# - symboling the maximum value is 3 n minmum is 2 and mean is 1
# - symboling the maximum value is 3 n minmum is 2 and mean is 1

# %% [markdown]
# ### Data Cleaning and Preparation

# %%
#Splitting company name from CarName column
CompanyName = df['CarName'].apply(lambda x : x.split(' ')[0])
df.insert(3,"CompanyName",CompanyName)
df.drop(['CarName'],axis=1,inplace=True)
df.head()
# Out:
#    symboling fueltype  CompanyName aspiration doornumber      carbody  \
# 0          3      gas  alfa-romero        std        two  convertible
# 1          3      gas  alfa-romero        std        two  convertible
# 2          1      gas  alfa-romero        std        two    hatchback
# 3          2      gas         audi        std       four        sedan
# 4          2      gas         audi        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0        rwd          front       88.6      168.8      64.1       48.8
# 1        rwd          front       88.6      168.8      64.1       48.8
# 2        rwd          front       94.5      171.2      65.5       52.4
# 3        fwd          front       99.8      176.6      66.2       54.3
# 4        4wd          front       99.4      176.6      66.4       54.3
#
#    curbweight enginetype cylindernumber  enginesize fuelsystem  boreratio  \
# ...

# %%
df.CompanyName.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %% [markdown]
# >Fixing invalid values
# There seems to be some spelling error in the CompanyName column.
#
#     - maxda = mazda
#     - Nissan = nissan
#     - porsche = porcshce
#     - toyota = toyouta
#     - vokswagen = volkswagen = vw

# %%
CompanyName =df.CompanyName.str.lower()
def correction(a,b):
    df.CompanyName.replace(a,b,inplace=True)
correction('maxda','mazda')
correction('porcshce','porsche')
correction('toyouta','toyota')
correction('vokswagen','volkswagen')
correction('vw','volkswagen')

df.CompanyName.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'buick', 'mercury', 'mitsubishi',
#        'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
df.CompanyName.value_counts()
# Out:
# toyota         32
# mazda          17
# nissan         17
# honda          13
# mitsubishi     13
# volkswagen     12
# subaru         12
# volvo          11
# peugeot        11
# dodge           9
# bmw             8
# buick           8
# audi            7
# plymouth        7
# saab            6
# porsche         5
# isuzu           4
# jaguar          3
# chevrolet       3
# alfa-romero     3
# renault         2
# mercury         1
# Nissan          1
# Name: CompanyName, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Visualizing the data

# %%
plt.figure(figsize=(25, 6))

plt.subplot(1,3,1)
plt1 = df.CompanyName.value_counts().plot(kind='bar')
plt.title('Companies Histogram')
plt1.set(xlabel = 'Car company', ylabel='Frequency of company')

plt.subplot(1,3,2)
plt1 = df.fueltype.value_counts().plot(kind='bar')
plt.title('Fuel Type Histogram')
plt1.set(xlabel = 'Fuel Type', ylabel='Frequency of fuel type')

plt.subplot(1,3,3)
plt1 = df.carbody.value_counts().plot(kind='bar')
plt.title('Car Type Histogram')
plt1.set(xlabel = 'Car Type', ylabel='Frequency of Car type')

plt.show()

# %% [markdown]
# - 1-toyota is most car company
# - 2-gas use more then diesel
# - 3-sedan is the top car type prefered.

# %%
plt.figure(figsize=(25, 6))

plt.subplot(1,3,1)
plt1 = df.doornumber.value_counts().plot(kind='bar')
plt.title('doornumber Histogram')
plt1.set(xlabel = 'doornumber', ylabel='Frequency of doornumber')

plt.subplot(1,3,2)
plt1 = df.cylindernumber.value_counts().plot(kind='bar')
plt.title('cylindernumber  Histogram')
plt1.set(xlabel = 'cylindernumber', ylabel='Frequency of cylindernumber')

plt.subplot(1,3,3)
plt1 = df.enginetype.value_counts().plot(kind='bar')
plt.title('enginetype Histogram')
plt1.set(xlabel = 'enginetype', ylabel='Frequency of enginetype')

plt.show()

# %% [markdown]
# - 1- four door more then 2
# - 2- four cvlinder most use
# - 3- ohc engine type more use

# %%
plt.figure(figsize=(25, 6))

plt.subplot(1,5,1)
plt1 = df.enginelocation.value_counts().plot(kind='bar')
plt.title('enginelocation Histogram')
plt1.set(xlabel = 'enginelocation', ylabel='Frequency of enginelocatio')

plt.subplot(1,5,2)
plt1 = df.fuelsystem.value_counts().plot(kind='bar')
plt.title('fuelsystem  Histogram')
plt1.set(xlabel = 'fuelsystem', ylabel='Frequency of fuelsystem')

plt.subplot(1,5,3)
plt1 = df.drivewheel.value_counts().plot(kind='bar')
plt.title('drivewheel Histogram')
plt1.set(xlabel = 'drivewheel', ylabel='Frequency of drivewheel')


plt.subplot(1,5,4)
plt1 = df.aspiration.value_counts().plot(kind='bar')
plt.title('aspiration Histogram')
plt1.set(xlabel = 'aspiration', ylabel='Frequency of aspiration')




plt.show()

# %% [markdown]
# - 1-front enginelocation more then rear
# - 2- mpfi fuelsystem is most one use
# - 3- fwd drivewheel max one
# - 4- std aspiration most use

# %%
plt.figure(figsize=(25, 6))

plt.subplot(1,5,1)
plt1 = df.symboling.value_counts().plot(kind='bar')
plt.title('symboling Histogram')
plt1.set(xlabel = 'symboling', ylabel='Frequency of symboling')

plt.subplot(1,5,2)
plt1 = df.wheelbase.value_counts().plot(kind='bar')
plt.title('wheelbase  Histogram')
plt1.set(xlabel = 'wheelbase', ylabel='Frequency of wheelbase')

plt.subplot(1,5,3)
plt1 = df.citympg.value_counts().plot(kind='bar')
plt.title('citympg Histogram')
plt1.set(xlabel = 'citympg', ylabel='Frequency of citympg')



plt.show()

# %%
plt.figure(figsize=(25, 6))


plt.subplot(1,2,1)
plt1 = df.stroke.value_counts().plot(kind='bar')
plt.title('stroke Histogram')
plt1.set(xlabel = 'stroke', ylabel='Frequency of stroke')


plt.subplot(1,2,2)
plt1 = df.horsepower.value_counts().plot(kind='bar')
plt.title('horsepower  Histogram')
plt1.set(xlabel = 'horsepower', ylabel='Frequency of horsepower')



plt.show()

# %%
plt.figure(figsize=(25, 6))

plt.subplot(1,5,1)
plt1 = df.carlength.value_counts().plot(kind='hist')
plt.title('carlength Histogram')
plt1.set(xlabel = 'carlength', ylabel='Frequency of carlength')

plt.subplot(1,5,2)
plt1 = df.carwidth.value_counts().plot(kind='hist')
plt.title('carwidth  Histogram')
plt1.set(xlabel = 'carwidth', ylabel='Frequency of carwidth')

plt.subplot(1,5,3)
plt1 = df.carheight.value_counts().plot(kind='hist')
plt.title('carheight Histogram')
plt1.set(xlabel = 'carheight', ylabel='Frequency of carheight')


plt.subplot(1,5,4)
plt1 = df.curbweight.value_counts().plot(kind='hist')
plt.title('curbweight Histogram')
plt1.set(xlabel = 'curbweight', ylabel='Frequency of curbweight')




plt.show()

# %%
plt.figure(figsize=(25, 6))

plt.subplot(1,6,1)
plt1 = df.enginesize.value_counts().plot(kind='hist')
plt.title('enginesize Histogram')
plt1.set(xlabel = 'enginesize', ylabel='Frequency of enginesize')

plt.subplot(1,6,2)
plt1 = df.boreratio.value_counts().plot(kind='hist')
plt.title('boreratio  Histogram')
plt1.set(xlabel = 'boreratio', ylabel='Frequency of boreratio')

plt.subplot(1,6,3)
plt1 = df.stroke.value_counts().plot(kind='hist')
plt.title('stroke Histogram')
plt1.set(xlabel = 'stroke', ylabel='Frequency of stroke')


plt.subplot(1,6,4)
plt1 = df.peakrpm.value_counts().plot(kind='hist')
plt.title('peakrpm Histogram')
plt1.set(xlabel = 'peakrpm', ylabel='Frequency of peakrpm')

plt.subplot(1,6,5)
plt1 = df.highwaympg.value_counts().plot(kind='hist')
plt.title('highwaympg Histogram')
plt1.set(xlabel = 'highwaympg', ylabel='Frequency of highwaympg')

plt.subplot(1,6,6)
plt1 = df.price.value_counts().plot(kind='hist')
plt.title('price Histogram')
plt1.set(xlabel = 'price', ylabel='Frequency of price')




plt.show()

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('Symboling Histogram')
sns.countplot(df.symboling, palette=("cubehelix"))

plt.subplot(1,2,2)
plt.title('Symboling vs Price')
sns.boxplot(x=df.symboling, y=df.price, palette=("cubehelix"))

plt.show()
# Out:
# E:\download\anconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# - Symboling 0 most use but  -1 is expencive and 1 is cheap

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('enginetype Histogram')
sns.countplot(df.enginetype, palette=("cubehelix"))

plt.subplot(1,2,2)
plt.title('enginetype vs Price')
sns.boxplot(x=df.enginetype, y=df.price, palette=("cubehelix"))

plt.show()
# Out:
# E:\download\anconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# - enginetype ohc most use but  ohcv is expencive and ohcf is cheap

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('fueltype Histogram')
sns.countplot(df.fueltype, palette=("cubehelix"))

plt.subplot(1,2,2)
plt.title('fueltype vs Price')
sns.boxplot(x=df.fueltype, y=df.price, palette=("cubehelix"))

plt.show()
# Out:
# E:\download\anconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# - fueltype gas most use but diesel is expencive and gas is cheap

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,2)
plt.title('CompanyName vs Price')
sns.boxplot(x=df.CompanyName, y=df.price, palette=("cubehelix"))
plt.subplot(1,2,2)
plt.title('doornumber vs Price')
sns.boxplot(x=df.doornumber, y=df.price, palette=("cubehelix"))

plt.show()
# Out:
# <ipython-input-27-87500f073556>:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(1,2,2)

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,4,1)
plt.title('aspiration vs Price')
sns.boxplot(x=df.aspiration, y=df.price, palette=("cubehelix"))
plt.subplot(1,4,2)
plt.title('drivewheel vs Price')
sns.boxplot(x=df.drivewheel, y=df.price, palette=("cubehelix"))
plt.subplot(1,4,3)
plt.title('cylindernumber vs Price')
sns.boxplot(x=df.cylindernumber, y=df.price, palette=("cubehelix"))
plt.subplot(1,4,4)
plt.title('enginelocation vs Price')
sns.boxplot(x=df.enginelocation, y=df.price, palette=("cubehelix"))


plt.show()

# %% [markdown]
# - 1-aspiration std is max but turbo is expencive
# - 3-cly 4 is max but 6 is expencive
# - 4-location of enging front is max but rear is expencive
# - 4-drivewheel fwd is max but rwd is expencive

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('carbody vs Price')
sns.boxplot(x=df.carbody, y=df.price, palette=("cubehelix"))
plt.subplot(1,2,2)
plt.title('fuelsystem vs Price')
sns.boxplot(x=df.fuelsystem, y=df.price, palette=("cubehelix"))

plt.show()

# %% [markdown]
# - 1-carbody sedan is max but hardtop is expencive
# - 2-fulsystem mpfi is max but idi is expencive

# %% [markdown]
# #### Visualising numerical data

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,4,1)
plt.title('wheelbase vs Price')
sns.scatterplot(x=df.wheelbase, y=df.price, palette=("cubehelix"))
plt.subplot(1,4,2)
plt.title('carlength vs Price')
sns.scatterplot(x=df.carlength, y=df.price, palette=("cubehelix"))
plt.subplot(1,4,3)
plt.title('carwidth vs Price')
sns.scatterplot(x=df.carwidth, y=df.price, palette=("cubehelix"))
plt.subplot(1,4,4)
plt.title('carheight vs Price')
sns.scatterplot(x=df.carheight, y=df.price, palette=("cubehelix"))


plt.show()

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,4,1)
plt.title('curbweight vs Price')
sns.scatterplot(x=df.curbweight, y=df.price, palette=("cubehelix"))
plt.subplot(1,4,2)

plt.title('enginesize vs Price')
sns.scatterplot(x=df.enginesize, y=df.price, palette=("cubehelix"))
plt.subplot(1,4,3)
plt.title('boreratio vs Price')
sns.scatterplot(x=df.boreratio, y=df.price, palette=("cubehelix"))


plt.show()

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,4,1)
plt.title('horsepower vs Price')
sns.scatterplot(x=df.horsepower, y=df.price, palette=("cubehelix"))
plt.subplot(1,4,2)
plt.title('peakrpm vs Price')
sns.scatterplot(x=df.peakrpm, y=df.price, palette=("cubehelix"))
plt.subplot(1,4,3)
plt.title('citympg vs Price')
sns.scatterplot(x=df.citympg, y=df.price, palette=("cubehelix"))
plt.subplot(1,4,4)
plt.title('highwaympg vs Price')
sns.scatterplot(x=df.highwaympg, y=df.price, palette=("cubehelix"))


plt.show()

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('stroke vs Price')
sns.scatterplot(x=df.stroke, y=df.price, palette=("cubehelix"))
plt.subplot(1,2,2)
plt.title('compressionratio vs Price')
sns.scatterplot(x=df.compressionratio, y=df.price, palette=("cubehelix"))


plt.show()

# %% [markdown]
# #### List of significant variables after Visual analysis :

# %% [markdown]
# - price
# - Engine Type
# - Fuel type
# - Car Body
# - Aspiration
# - Cylinder Number
# - Drivewheel
# - Curbweight
# - citympg
# - highwaympg
# - Car Length
# - Car width
# - Engine Size
# - Boreratio
# - Horse Power
# - Wheel base

# %%
cars_lr = df[['price', 'fueltype', 'aspiration','carbody', 'drivewheel','wheelbase',
                  'curbweight', 'enginetype', 'cylindernumber', 'enginesize', 'boreratio','horsepower', 
                     'carlength','carwidth', 'citympg','highwaympg']]
cars_lr.head()
# Out:
#      price fueltype aspiration      carbody drivewheel  wheelbase  curbweight  \
# 0  13495.0      gas        std  convertible        rwd       88.6        2548
# 1  16500.0      gas        std  convertible        rwd       88.6        2548
# 2  16500.0      gas        std    hatchback        rwd       94.5        2823
# 3  13950.0      gas        std        sedan        fwd       99.8        2337
# 4  17450.0      gas        std        sedan        4wd       99.4        2824
#
#   enginetype cylindernumber  enginesize  boreratio  horsepower  carlength  \
# 0       dohc           four         130       3.47         111      168.8
# 1       dohc           four         130       3.47         111      168.8
# 2       ohcv            six         152       2.68         154      171.2
# 3        ohc           four         109       3.19         102      176.6
# 4        ohc           five         136       3.19         115      176.6
#
#    carwidth  citympg  highwaympg
# ...

# %%
cars_lr["fueltype"]=cars_lr["fueltype"].replace({"gas":0,"diesel":1})
cars_lr["aspiration"]=cars_lr["aspiration"].replace({"std":0,"turbo":1})
cars_lr["carbody"]=cars_lr["carbody"].replace({"sedan":0,"hatchback":1,"wagon":2,"hardtop":3,"convertible":4})
cars_lr["drivewheel"]=cars_lr["drivewheel"].replace({"fwd":0,"rwd":1,"4wd":2})
cars_lr["enginetype"]=cars_lr["enginetype"].replace({"ohc":0,"ohcf":1,"ohcv":2,"dohc":3,"l":4,"rotor":5,"dohcv":6})
cars_lr["cylindernumber"]=cars_lr["cylindernumber"].replace({"four":0,"six":1,"five":2,"eight":3,"two":4,"three":5,"twelve":6})
# Out:
# <ipython-input-35-d5e7be99e802>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars_lr["fueltype"]=cars_lr["fueltype"].replace({"gas":0,"diesel":1})
# <ipython-input-35-d5e7be99e802>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars_lr["aspiration"]=cars_lr["aspiration"].replace({"std":0,"turbo":1})
# <ipython-input-35-d5e7be99e802>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
cars_lr.head()
# Out:
#      price  fueltype  aspiration  carbody  drivewheel  wheelbase  curbweight  \
# 0  13495.0         0           0        4           1       88.6        2548
# 1  16500.0         0           0        4           1       88.6        2548
# 2  16500.0         0           0        1           1       94.5        2823
# 3  13950.0         0           0        0           0       99.8        2337
# 4  17450.0         0           0        0           2       99.4        2824
#
#    enginetype  cylindernumber  enginesize  boreratio  horsepower  carlength  \
# 0           3               0         130       3.47         111      168.8
# 1           3               0         130       3.47         111      168.8
# 2           2               1         152       2.68         154      171.2
# 3           0               0         109       3.19         102      176.6
# 4           0               2         136       3.19         115      176.6
#
#    carwidth  citympg  highwaympg
# ...

# %% [markdown]
# ### modeling

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import accuracy_score

# %%
scaler=MinMaxScaler()
num_vars = ['wheelbase', 'curbweight', 'enginesize', 'boreratio', 'horsepower','citympg','highwaympg','carlength','carwidth','price']
cars_lr[num_vars] = scaler.fit_transform(cars_lr[num_vars])
# Out:
# <ipython-input-38-81c5b7ddd402>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars_lr[num_vars] = scaler.fit_transform(cars_lr[num_vars])
# E:\download\anconda\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)

# %%
x = cars_lr.iloc[:,:-1]
y = cars_lr.iloc[:,-1]

# %%
print(x.shape)
print(y.shape)
# Out:
# (205, 15)
# (205,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.7,random_state=100)

# %%
lm = LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print('Linear Regression Train Score is : ' , lm.score(x_train, y_train))
print('Linear Regression Test Score is : ' , lm.score(x_test, y_test))
print('Linear Regression Coef is : ' , lm.coef_)
print('Linear Regression intercept is : ' , lm.intercept_)
# Out:
# Linear Regression Train Score is :  0.9814162854004364
# Linear Regression Test Score is :  0.9332813003443328
# Linear Regression Coef is :  [ 0.01949369  0.07790786 -0.05713584  0.00367949 -0.03387648 -0.02807048
#   0.01394217  0.00156184 -0.01082935 -0.21188077  0.01325517  0.32969176
#   0.03445724 -0.15475591  0.92910157]
# Linear Regression intercept is :  0.12266774901009325

# %%
y_pred=lm.predict(x_test)
mean_absolute_error(y_test, y_pred)
# Out:
# 0.03336858922105089

# %%
lm = SVR(gamma='scale', C=0.5, epsilon=0.003)
lm.fit(x_train,y_train)
print('SVR Train Score is : ' , lm.score(x_train, y_train))
print('SVR Test Score is : ' , lm.score(x_test, y_test))
# Out:
# SVR Train Score is :  0.8688657066683971
# SVR Test Score is :  0.8839049811658194

# %%
y_pred=lm.predict(x_test)
mean_absolute_error(y_test, y_pred)
# Out:
# 0.04151417811932648
